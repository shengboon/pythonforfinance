# %% [markdown]
# <h2> Portfolio Analysis</h2>

# %% [markdown]
# Reading the data

# %%
import pandas as pd

# %%
df = pd.read_excel('../data/Portfolio.xls')

# %% [markdown]
# Inspecting the data

# %%
idx = df['country'] == 'Switzerland'
df_swiss = df.loc[idx,:]
df_swiss.set_index('date',inplace=True)
df_mini_swiss = df_swiss.loc['2018-01-31',:]

# %% [markdown]
# <h3>Rebase exposure </h3>

# %%
df['exposure%'] = df['exposure']/df['nav']
df['mtd%'] = df['mtd']/df['nav']

# %% [markdown]
# <h3>Top Winners and Losers</h3>

# %% [markdown]
# group by issuer

# %%
df_issuer = df.groupby('issuer').sum()

# %% [markdown]
# create group of winners and losers

# %%
idx_winner = df_issuer['mtd%']>0
df_winner = df_issuer.loc[idx_winner,:].copy()
df_winner.sort_values(by='mtd%',ascending=False,inplace=True)

idx_loser = df_issuer['mtd%']<0
df_loser = df_issuer.loc[idx_loser,:].copy()
df_loser.sort_values(by='mtd%',ascending=True,inplace=True)

# %%
print('Top Winners')
print(df_winner['mtd%'].head()*100)
print('------------------------------\n')
print('Top Losers')
print(df_loser['mtd%'].head()*100)
# Out:
# Top Winners
# issuer
# Sky PLC            3.959677
# CME Group Inc      3.172502
# CVS Health Corp    3.027441
# INFORMA PLC        2.622253
# Worldpay Inc       2.585200
# Name: mtd%, dtype: float64
# ------------------------------
#
# Top Losers
# issuer
# Cobalt 27 Capital Corp   -4.614026
# Spaxs SpA                -3.156713
# NEX Group PLC            -2.969552
# NXP Semiconductors NV    -2.877571
# Aetna Inc                -2.771514
# Name: mtd%, dtype: float64

# %% [markdown]
# <h3> PNL by Strategy </h3>

# %%
df.groupby('strategy').sum()['mtd%']*100
# Out:
# strategy
# ARBITRAGE              1.269347
# CAPITAL MARKETS      -21.167305
# SPECIAL SITUATIONS    -0.721946
# Name: mtd%, dtype: float64

# %% [markdown]
# <h3>Evolution of the Fund NAV (AUM)</h3>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# to make sure we have good looking graphs : add seaborn

# %%
import seaborn as sns
sns.set()

# %%
df_aum = df.groupby('date').mean()

# %%
print('AUM')
df_aum['nav'].head()
# Out:
# AUM
# date
# 2018-01-31    1.884133e+08
# 2018-02-28    1.901977e+08
# 2018-03-30    1.924677e+08
# 2018-04-30    2.003713e+08
# 2018-05-31    2.027182e+08
# Name: nav, dtype: float64

# %%
figure , ax = plt.subplots(1,1,figsize = (15,5))
ax.plot(df_aum.index,df_aum['nav']/1e6)
ax.set_title('Evolution of AUM',fontsize=14)
ax.set_ylabel('$M ')
ax.set_xlabel('T');

# %% [markdown]
# <h3>Plotting the exposure and PNL across the different strategies </h3>

# %%
print('The strategies are :')
for strat in df['strategy'].unique():
    print(strat)
# Out:
# The strategies are :
# SPECIAL SITUATIONS
# CAPITAL MARKETS
# ARBITRAGE

# %%
figure , ax = plt.subplots(2,1,figsize = (10,8),sharex=True)

for strat in df['strategy'].unique():
    idx = df['strategy'] == strat
    df_strat = df.loc[idx,:].copy()
    df_strat = df_strat.groupby('date').sum()
    ax[0].plot(df_strat.index,df_strat['mtd%'].cumsum()*100,label=strat)
    ax[1].plot(df_strat.index,df_strat['exposure%']*100,label=strat)

ax[0].legend(fontsize=14);
ax[0].set_title('PNL %',fontsize=14)
ax[1].set_title('Exposure %',fontsize=14);

# %% [markdown]
# <h3> Attribution of YTD PNL by Sector / Country </h3>

# %%
import numpy as np

# %%
df_pivot =df.pivot_table(columns='country',
               index='sector',
               values='mtd%',
               aggfunc=np.sum,
               margins=True,
               margins_name='TOTAL')

# %%
df_pivot.fillna(value=0,inplace=True)
df_pivot
# Out:
# country                 Australia   Austria   Belgium    Canada  \
# sector
# Basic Materials          0.000000  0.000000  0.001717 -0.046111
# Communications           0.000000  0.000000  0.005109  0.000000
# Consumer, Cyclical       0.000000  0.000000  0.000000  0.000000
# Consumer, Non-cyclical   0.000231  0.000000  0.000047  0.000652
# Diversified              0.000000  0.000000  0.000000  0.000000
# Energy                   0.000000  0.000000  0.000000  0.000000
# Financial                0.000000  0.001234  0.000000  0.001160
# Funds                    0.000000  0.000000  0.000000  0.000000
# Future                   0.000000  0.000000  0.000000  0.000000
# Government               0.000000  0.000000  0.000000  0.000000
# Index                    0.000000  0.000000  0.000000  0.000000
# Industrial               0.000000  0.000000 -0.000642 -0.000037
# Technology               0.000000  0.000000  0.000000 -0.000045
# Unspecified Sector      -0.000513  0.000000  0.000000  0.000000
# Utilities                0.000000  0.000000  0.000000  0.000000
# TOTAL                   -0.000282  0.001234  0.006231 -0.044381
#
# country                 Cayman Islands  Cyprus   Denmark       EMU    Europe  \
# sector
# Basic Materials               0.000000     0.0  0.000000  0.000000  0.000000
# Communications                0.000000     0.0  0.000090  0.000000  0.000000
# Consumer, Cyclical            0.000000     0.0  0.000000  0.000000  0.000000
# Consumer, Non-cyclical        0.000000     0.0 -0.008091  0.000000  0.000000
# Diversified                   0.000000     0.0  0.000000  0.000000  0.000000
# Energy                       -0.000497     0.0  0.000000  0.000000  0.000000
# Financial                    -0.000237     0.0  0.001694  0.000000  0.000000
# Funds                         0.000000     0.0  0.000000  0.000000  0.000000
# Future                        0.000000     0.0  0.000000 -0.003964  0.000000
# Government                    0.000000     0.0  0.000000  0.000000  0.000000
# Index                         0.000000     0.0  0.000000 -0.000099 -0.000039
# Industrial                    0.000000     0.0  0.000000  0.000000  0.000000
# Technology                    0.000000     0.0  0.000923  0.000000  0.000000
# Unspecified Sector            0.000000     0.0  0.000000  0.000000  0.000000
# Utilities                     0.000000     0.0  0.000000  0.000000  0.000000
# TOTAL                        -0.000734     0.0 -0.005385 -0.004063 -0.000039
#
# country                  Finland    ...     Singapore  South Africa     Spain  \
# sector                              ...
# Basic Materials         0.000000    ...           0.0      0.000000  0.000000
# Communications          0.000000    ...           0.0     -0.006750 -0.000164
# Consumer, Cyclical      0.000031    ...           0.0      0.000000  0.000000
# Consumer, Non-cyclical  0.000000    ...           0.0      0.000000 -0.000264
# Diversified             0.000000    ...           0.0      0.000000  0.000000
# Energy                  0.000000    ...           0.0      0.000000  0.000000
# Financial               0.000215    ...           0.0     -0.001362 -0.008255
# Funds                   0.000000    ...           0.0      0.000000  0.000000
# Future                  0.000000    ...           0.0      0.000000  0.000000
# Government              0.000000    ...           0.0      0.000000  0.000000
# Index                   0.000000    ...           0.0      0.000000  0.000000
# Industrial              0.000000    ...           0.0      0.000000 -0.002709
# Technology             -0.008958    ...           0.0      0.000000  0.000000
# Unspecified Sector      0.000000    ...           0.0      0.000000  0.000000
# Utilities               0.000000    ...           0.0      0.000000  0.000167
# TOTAL                  -0.008712    ...           0.0     -0.008112 -0.011225
#
# country                 Swaziland    Sweden  Switzerland    Turkey  \
# sector
# Basic Materials          0.000000 -0.000631     0.000147  0.000000
# Communications           0.000000 -0.001055     0.000000  0.000000
# Consumer, Cyclical       0.000000 -0.006131     0.000000  0.000090
# Consumer, Non-cyclical   0.000000  0.000977    -0.010355 -0.000116
# Diversified              0.000000  0.000000     0.000000  0.000000
# Energy                   0.000000  0.008061     0.000000  0.000000
# Financial                0.000000  0.000000    -0.000413  0.000000
# Funds                    0.000000  0.000000     0.000000  0.000000
# Future                   0.000000  0.000000     0.000000  0.000000
# Government               0.000000  0.000000     0.000000  0.000062
# Index                    0.000000  0.000000     0.000000  0.000000
# Industrial               0.000000  0.000000    -0.000406  0.000000
# Technology               0.000000 -0.008779     0.000743  0.000000
# Unspecified Sector       0.000000  0.000000     0.000000  0.000000
# Utilities                0.000168  0.000476     0.000000  0.000150
# TOTAL                    0.000168 -0.007082    -0.010284  0.000185
#
# country                 United Kingdom  United States     TOTAL
# sector
# Basic Materials           3.858460e-03       0.002848 -0.022791
# Communications            6.484414e-02       0.018696  0.082492
# Consumer, Cyclical       -9.634700e-03      -0.000159 -0.044681
# Consumer, Non-cyclical   -3.642915e-02       0.041400 -0.028629
# Diversified               0.000000e+00       0.001016 -0.031776
# Energy                   -1.452660e-02       0.000000 -0.006799
# Financial                -6.594543e-02       0.001539 -0.082470
# Funds                     0.000000e+00      -0.002090 -0.002090
# Future                   -1.493963e-03      -0.002912  0.004022
# Government                0.000000e+00       0.000000  0.000062
# Index                     0.000000e+00       0.000178 -0.002194
# Industrial               -3.482252e-03       0.002501 -0.007859
# Technology               -7.254760e-03      -0.042969 -0.066396
# Unspecified Sector        0.000000e+00       0.001399  0.000886
# Utilities                 2.374004e-11       0.002160  0.002025
# TOTAL                    -7.006426e-02       0.023605 -0.206199
#
# [16 rows x 41 columns]

# %% [markdown]
# Get rid of the NAN - in the pivot table

# %%
df.pivot_table(columns='country',
               index='sector',
               values='mtd%',
               aggfunc=np.sum,
               margins=True,
               margins_name='TOTAL').fillna(value=0)*100
# Out:
# country                 Australia   Austria   Belgium    Canada  \
# sector
# Basic Materials          0.000000  0.000000  0.171726 -4.611071
# Communications           0.000000  0.000000  0.510863  0.000000
# Consumer, Cyclical       0.000000  0.000000  0.000000  0.000000
# Consumer, Non-cyclical   0.023090  0.000000  0.004723  0.065189
# Diversified              0.000000  0.000000  0.000000  0.000000
# Energy                   0.000000  0.000000  0.000000  0.000000
# Financial                0.000000  0.123372  0.000000  0.116002
# Funds                    0.000000  0.000000  0.000000  0.000000
# Future                   0.000000  0.000000  0.000000  0.000000
# Government               0.000000  0.000000  0.000000  0.000000
# Index                    0.000000  0.000000  0.000000  0.000000
# Industrial               0.000000  0.000000 -0.064201 -0.003671
# Technology               0.000000  0.000000  0.000000 -0.004506
# Unspecified Sector      -0.051296  0.000000  0.000000  0.000000
# Utilities                0.000000  0.000000  0.000000  0.000000
# TOTAL                   -0.028206  0.123372  0.623112 -4.438056
#
# country                 Cayman Islands  Cyprus   Denmark       EMU    Europe  \
# sector
# Basic Materials               0.000000     0.0  0.000000  0.000000  0.000000
# Communications                0.000000     0.0  0.008961  0.000000  0.000000
# Consumer, Cyclical            0.000000     0.0  0.000000  0.000000  0.000000
# Consumer, Non-cyclical        0.000000     0.0 -0.809123  0.000000  0.000000
# Diversified                   0.000000     0.0  0.000000  0.000000  0.000000
# Energy                       -0.049705     0.0  0.000000  0.000000  0.000000
# Financial                    -0.023720     0.0  0.169366  0.000000  0.000000
# Funds                         0.000000     0.0  0.000000  0.000000  0.000000
# Future                        0.000000     0.0  0.000000 -0.396365  0.000000
# Government                    0.000000     0.0  0.000000  0.000000  0.000000
# Index                         0.000000     0.0  0.000000 -0.009944 -0.003884
# Industrial                    0.000000     0.0  0.000000  0.000000  0.000000
# Technology                    0.000000     0.0  0.092330  0.000000  0.000000
# Unspecified Sector            0.000000     0.0  0.000000  0.000000  0.000000
# Utilities                     0.000000     0.0  0.000000  0.000000  0.000000
# TOTAL                        -0.073425     0.0 -0.538466 -0.406309 -0.003884
#
# country                  Finland    ...      Singapore  South Africa  \
# sector                              ...
# Basic Materials         0.000000    ...            0.0      0.000000
# Communications          0.000000    ...            0.0     -0.675014
# Consumer, Cyclical      0.003062    ...            0.0      0.000000
# Consumer, Non-cyclical  0.000000    ...            0.0      0.000000
# Diversified             0.000000    ...            0.0      0.000000
# Energy                  0.000000    ...            0.0      0.000000
# Financial               0.021465    ...            0.0     -0.136186
# Funds                   0.000000    ...            0.0      0.000000
# Future                  0.000000    ...            0.0      0.000000
# Government              0.000000    ...            0.0      0.000000
# Index                   0.000000    ...            0.0      0.000000
# Industrial              0.000000    ...            0.0      0.000000
# Technology             -0.895767    ...            0.0      0.000000
# Unspecified Sector      0.000000    ...            0.0      0.000000
# Utilities               0.000000    ...            0.0      0.000000
# TOTAL                  -0.871240    ...            0.0     -0.811200
#
# country                    Spain  Swaziland    Sweden  Switzerland    Turkey  \
# sector
# Basic Materials         0.000000   0.000000 -0.063080     0.014667  0.000000
# Communications         -0.016362   0.000000 -0.105491     0.000000  0.000000
# Consumer, Cyclical      0.000000   0.000000 -0.613101     0.000000  0.008977
# Consumer, Non-cyclical -0.026395   0.000000  0.097662    -1.035545 -0.011611
# Diversified             0.000000   0.000000  0.000000     0.000000  0.000000
# Energy                  0.000000   0.000000  0.806079     0.000000  0.000000
# Financial              -0.825532   0.000000  0.000000    -0.041284  0.000000
# Funds                   0.000000   0.000000  0.000000     0.000000  0.000000
# Future                  0.000000   0.000000  0.000000     0.000000  0.000000
# Government              0.000000   0.000000  0.000000     0.000000  0.006160
# Index                   0.000000   0.000000  0.000000     0.000000  0.000000
# Industrial             -0.270882   0.000000  0.000000    -0.040601  0.000000
# Technology              0.000000   0.000000 -0.877902     0.074314  0.000000
# Unspecified Sector      0.000000   0.000000  0.000000     0.000000  0.000000
# Utilities               0.016703   0.016795  0.047619     0.000000  0.014983
# TOTAL                  -1.122467   0.016795 -0.708214    -1.028450  0.018510
#
# country                 United Kingdom  United States      TOTAL
# sector
# Basic Materials           3.858460e-01       0.284840  -2.279089
# Communications            6.484414e+00       1.869553   8.249228
# Consumer, Cyclical       -9.634700e-01      -0.015947  -4.468133
# Consumer, Non-cyclical   -3.642915e+00       4.140047  -2.862935
# Diversified               0.000000e+00       0.101588  -3.177595
# Energy                   -1.452660e+00       0.000000  -0.679928
# Financial                -6.594543e+00       0.153894  -8.246978
# Funds                     0.000000e+00      -0.209012  -0.209012
# Future                   -1.493963e-01      -0.291182   0.402175
# Government                0.000000e+00       0.000000   0.006160
# Index                     0.000000e+00       0.017773  -0.219386
# Industrial               -3.482252e-01       0.250111  -0.785880
# Technology               -7.254760e-01      -4.296942  -6.639629
# Unspecified Sector        0.000000e+00       0.139859   0.088563
# Utilities                 2.374004e-09       0.215950   0.202535
# TOTAL                    -7.006426e+00       2.360532 -20.619904
#
# [16 rows x 41 columns]
